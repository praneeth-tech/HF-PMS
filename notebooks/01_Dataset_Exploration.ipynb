# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-560829f4-7059-4e75-b5f1-670ad03fc97e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-560829f4-7059-4e75-b5f1-670ad03fc97e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel("Pharma_Patient_Dataset_60_Records.xlsx")

print("Dataset Loaded Successfully")
# Out:
# Dataset Loaded Successfully

# %%
print("Number of Rows and Columns:")
print(df.shape)
# Out:
# Number of Rows and Columns:
# (60, 15)

# %%
df.head()
# Out:
#    Patient ID Patient\nName  Age  Gender       Disease  Drug\nName  \
# 0     1345002        Ananya   60    Male  Hypertension  Amlodipine
# 1     1345003         Kavya   37  Female  Hypertension  Amlodipine
# 2     1345004        Ananya   67    Male      Migraine  Topiramate
# 3     1345005         Meera   30    Male      Diabetes   Metformin
# 4     1345006        Ananya   28    Male     Arthritis    Naproxen
#
#    Dosage \nmg  Frequency\nPer Day  Treatment\nDuration Days Severity \nLevel  \
# 0         22.5                   1                        58           Severe
# 1         70.2                   2                        39           Severe
# 2         89.5                   2                        37           Severe
# 3         51.2                   2                        92         Moderate
# 4         17.4                   3                        47         Moderate
#
#    Follow \nUp Count Side \nEffects  Recovery \nRate Percent  Doctor \nRating  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Patient ID               60 non-null     int64
#  1   Patient
# Name             60 non-null     object
#  2   Age                      60 non-null     int64
#  3   Gender                   60 non-null     object
#  4   Disease                  60 non-null     object
#  5   Drug
# Name                60 non-null     object
#  6   Dosage
# mg               60 non-null     float64
#  7   Frequency
# Per Day        60 non-null     int64
#  8   Treatment
# Duration Days  60 non-null     int64
#  9   Severity
# Level          60 non-null     object
#  10  Follow
# Up Count         60 non-null     int64
#  11  Side
# Effects            60 non-null     object
#  12  Recovery
# Rate Percent   60 non-null     int64
#  13  Doctor
# Rating           60 non-null     float64
# ...

# %%
print(df.columns)
# Out:
# Index(['Patient ID', 'Patient\nName', 'Age', 'Gender', 'Disease', 'Drug\nName',
#        'Dosage \nmg', 'Frequency\nPer Day', 'Treatment\nDuration Days',
#        'Severity \nLevel', 'Follow \nUp Count', 'Side \nEffects',
#        'Recovery \nRate Percent', 'Doctor \nRating', 'Outcome'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Patient ID                  0
# Patient\nName               0
# Age                         0
# Gender                      0
# Disease                     0
# Drug\nName                  0
# Dosage \nmg                 0
# Frequency\nPer Day          0
# Treatment\nDuration Days    0
# Severity \nLevel            0
# Follow \nUp Count           0
# Side \nEffects              0
# Recovery \nRate Percent     0
# Doctor \nRating             0
# Outcome                     0
# dtype: int64

# %%
df.describe()

# %%
df.describe()
# Out:
#          Patient ID        Age  Dosage \nmg  Frequency\nPer Day  \
# count  6.000000e+01  60.000000    60.000000           60.000000
# mean   1.345032e+06  43.650000    53.170000            1.983333
# std    1.746425e+01  17.000324    29.031434            0.812856
# min    1.345002e+06  18.000000     2.100000            1.000000
# 25%    1.345017e+06  28.750000    27.150000            1.000000
# 50%    1.345032e+06  41.500000    56.050000            2.000000
# 75%    1.345046e+06  58.500000    73.950000            3.000000
# max    1.345061e+06  74.000000    98.400000            3.000000
#
#        Treatment\nDuration Days  Follow \nUp Count  Recovery \nRate Percent  \
# count                 60.000000          60.000000                60.000000
# mean                  92.433333           4.666667                67.500000
# std                   50.301588           3.265986                19.063231
# min                    7.000000           1.000000                40.000000
# ...

# %%
df.describe(include='all')
# Out:
#           Patient ID Patient\nName        Age Gender   Disease   Drug\nName  \
# count   6.000000e+01            60  60.000000     60        60           60
# unique           NaN            19        NaN      2         5           10
# top              NaN        Vikram        NaN   Male  Migraine  Sumatriptan
# freq             NaN             7        NaN     31        16           11
# mean    1.345032e+06           NaN  43.650000    NaN       NaN          NaN
# std     1.746425e+01           NaN  17.000324    NaN       NaN          NaN
# min     1.345002e+06           NaN  18.000000    NaN       NaN          NaN
# 25%     1.345017e+06           NaN  28.750000    NaN       NaN          NaN
# 50%     1.345032e+06           NaN  41.500000    NaN       NaN          NaN
# 75%     1.345046e+06           NaN  58.500000    NaN       NaN          NaN
# max     1.345061e+06           NaN  74.000000    NaN       NaN          NaN
#
# ...

# %%
df['Disease'].value_counts()
# Out:
# Disease
# Migraine        16
# Arthritis       15
# Diabetes        13
# Hypertension    10
# Asthma           6
# Name: count, dtype: int64

# %%
df['Drug\nName'].value_counts()
# Out:
# Drug\nName
# Sumatriptan    11
# Ibuprofen       9
# Glimepiride     8
# Losartan        7
# Naproxen        6
# Topiramate      5
# Metformin       5
# Amlodipine      3
# Salbutamol      3
# Budesonide      3
# Name: count, dtype: int64

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# Not Recovered    25
# Recovered        20
# Improving        15
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      31
# Female    29
# Name: count, dtype: int64

# %%
print("Unique Diseases:")

print(df['Disease'].unique())
# Out:
# Unique Diseases:
# ['Hypertension' 'Migraine' 'Diabetes' 'Arthritis' 'Asthma']

# %%
print("Unique Drugs:")

print(df['Drug\nName'].unique())
# Out:
# Unique Drugs:
# ['Amlodipine' 'Topiramate' 'Metformin' 'Naproxen' 'Losartan' 'Glimepiride'
#  'Ibuprofen' 'Sumatriptan' 'Salbutamol' 'Budesonide']

# %%
average_recovery = df['Recovery \nRate Percent'].mean()

print("Average Recovery Rate:", average_recovery)
# Out:
# Average Recovery Rate: 67.5

# %%
average_duration = df['Treatment\nDuration Days'].mean()

print("Average Treatment Duration:", average_duration)
# Out:
# Average Treatment Duration: 92.43333333333334

# %%
print("Total Patients:", len(df))

print("Total Diseases:", df['Disease'].nunique())

print("Total Drugs:", df['Drug\nName'].nunique())

print("Average Recovery Rate:", round(df['Recovery \nRate Percent'].mean(),2))
# Out:
# Total Patients: 60
# Total Diseases: 5
# Total Drugs: 10
# Average Recovery Rate: 67.5
