# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
df = pd.read_csv('/content/diabetic_data.csv')

# %%
df.describe()
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  4.411000e+04  4.411000e+04       44110.000000
# mean   7.481923e+07  3.270408e+07           2.268284
# std    3.574129e+07  3.402587e+07           1.656407
# min    1.252200e+04  1.350000e+02           1.000000
# 25%    4.607805e+07  4.849060e+06           1.000000
# 50%    7.631726e+07  2.294122e+07           2.000000
# 75%    1.049085e+08  5.523694e+07           3.000000
# max    1.361026e+08  1.152184e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count              44110.000000         44110.000000      44110.000000
# mean                   4.390070             6.534437          4.576740
# std                    6.164643             4.929789          3.101507
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# 50%                    1.000000             7.000000          4.000000
# 75%                    5.000000             7.000000          6.000000
# max                   28.000000            20.000000         14.000000
#
#        num_lab_procedures  num_procedures  num_medications  number_outpatient  \
# count        44110.000000    44110.000000     44110.000000       44110.000000
# mean            43.108093        1.387577        15.298708           0.218159
# std             19.097930        1.699393         8.130653           0.881051
# min              1.000000        0.000000         1.000000           0.000000
# 25%             31.000000        0.000000        10.000000           0.000000
# 50%             44.000000        1.000000        14.000000           0.000000
# 75%             56.000000        2.000000        19.000000           0.000000
# max            129.000000        6.000000        81.000000          36.000000
#
#        number_emergency  number_inpatient  number_diagnoses
# count      44110.000000      44110.000000      44110.000000
# mean           0.117116          0.592133          6.812922
# std            0.616801          1.208829          2.030053
# min            0.000000          0.000000          1.000000
# 25%            0.000000          0.000000          5.000000
# 50%            0.000000          0.000000          7.000000
# 75%            0.000000          1.000000          9.000000
# max           42.000000         21.000000          9.000000

# %%
df.hist(figsize=(18,12), bins=20)
plt.tight_layout()
plt.show()

# %%
numeric_cols = df.select_dtypes(include=np.number).columns

for col in numeric_cols:
    plt.figure(figsize=(8,4))
    sns.kdeplot(df[col])
    plt.title(col)
    plt.show()

# %%
for col in numeric_cols:
    plt.figure(figsize=(8,4))
    sns.boxplot(x=df[col])
    plt.title(col)
    plt.show()

# %%
corr = df[numeric_cols].corr()
corr
# Out:
#                           encounter_id  patient_nbr  admission_type_id  \
# encounter_id                  1.000000     0.272222          -0.078475
# patient_nbr                   0.272222     1.000000           0.163418
# admission_type_id            -0.078475     0.163418           1.000000
# discharge_disposition_id     -0.182103    -0.173654           0.120196
# admission_source_id          -0.064304     0.060225           0.349072
# time_in_hospital             -0.044162     0.000724          -0.024912
# num_lab_procedures           -0.165110     0.017267          -0.188874
# num_procedures               -0.032021    -0.012387           0.071740
# num_medications               0.015580     0.011490           0.109182
# number_outpatient             0.102071     0.125659           0.121906
# number_emergency              0.107048     0.068720           0.038989
# number_inpatient              0.028529     0.037068          -0.025456
# number_diagnoses              0.036382     0.121337          -0.032761
#
#                           discharge_disposition_id  admission_source_id  \
# encounter_id                             -0.182103            -0.064304
# patient_nbr                              -0.173654             0.060225
# admission_type_id                         0.120196             0.349072
# discharge_disposition_id                  1.000000             0.010053
# admission_source_id                       0.010053             1.000000
# time_in_hospital                          0.135802            -0.038089
# num_lab_procedures                       -0.027860            -0.117791
# num_procedures                            0.025035            -0.164303
# num_medications                           0.096662            -0.027265
# number_outpatient                        -0.017263             0.170240
# number_emergency                         -0.020374             0.117267
# number_inpatient                          0.013565             0.038165
# number_diagnoses                          0.069425             0.130417
#
#                           time_in_hospital  num_lab_procedures  \
# encounter_id                     -0.044162           -0.165110
# patient_nbr                       0.000724            0.017267
# admission_type_id                -0.024912           -0.188874
# discharge_disposition_id          0.135802           -0.027860
# admission_source_id              -0.038089           -0.117791
# time_in_hospital                  1.000000            0.271834
# num_lab_procedures                0.271834            1.000000
# num_procedures                    0.233814            0.096857
# num_medications                   0.460132            0.200749
# number_outpatient                -0.023545           -0.065694
# number_emergency                 -0.017948           -0.058122
# number_inpatient                  0.080310            0.041810
# number_diagnoses                  0.266003            0.117779
#
#                           num_procedures  num_medications  number_outpatient  \
# encounter_id                   -0.032021         0.015580           0.102071
# patient_nbr                    -0.012387         0.011490           0.125659
# admission_type_id               0.071740         0.109182           0.121906
# discharge_disposition_id        0.025035         0.096662          -0.017263
# admission_source_id            -0.164303        -0.027265           0.170240
# time_in_hospital                0.233814         0.460132          -0.023545
# num_lab_procedures              0.096857         0.200749          -0.065694
# num_procedures                  1.000000         0.440873          -0.023147
# num_medications                 0.440873         1.000000           0.034026
# number_outpatient              -0.023147         0.034026           1.000000
# number_emergency               -0.038980         0.013399           0.129785
# number_inpatient               -0.064297         0.049326           0.084335
# number_diagnoses                0.113658         0.260424           0.087261
#
#                           number_emergency  number_inpatient  number_diagnoses
# encounter_id                      0.107048          0.028529          0.036382
# patient_nbr                       0.068720          0.037068          0.121337
# admission_type_id                 0.038989         -0.025456         -0.032761
# discharge_disposition_id         -0.020374          0.013565          0.069425
# admission_source_id               0.117267          0.038165          0.130417
# time_in_hospital                 -0.017948          0.080310          0.266003
# num_lab_procedures               -0.058122          0.041810          0.117779
# num_procedures                   -0.038980         -0.064297          0.113658
# num_medications                   0.013399          0.049326          0.260424
# number_outpatient                 0.129785          0.084335          0.087261
# number_emergency                  1.000000          0.222453          0.052515
# number_inpatient                  0.222453          1.000000          0.132445
# number_diagnoses                  0.052515          0.132445          1.000000

# %%
plt.figure(figsize=(14,10))

sns.heatmap(
    corr,
    annot=True,
    cmap='coolwarm'
)

plt.title('Correlation Matrix')
plt.show()

# %%
sns.pairplot(df[numeric_cols])
plt.show()

# %%
df[numeric_cols].skew()
# Out:
# encounter_id                -0.146673
# patient_nbr                  1.023544
# admission_type_id            1.264269
# discharge_disposition_id     2.013653
# admission_source_id          0.984582
# time_in_hospital             1.061432
# num_lab_procedures          -0.123162
# num_procedures               1.230869
# num_medications              1.485678
# number_outpatient            9.536715
# number_emergency            18.326009
# number_inpatient             3.660828
# number_diagnoses            -0.473474
# dtype: float64
